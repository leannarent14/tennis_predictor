# %%
import pandas as pd
import numpy as np

# %%
file_path = "../tennis_predictor/Resources/original_data/match_stats_2017.csv"

# %%
stats_df = pd.read_csv(file_path)

# %%
stats_df.head()
# Out:
#    tourney_order            match_id                 match_stats_url_suffix  \
# 0              0  2017-339-r975-n409  /en/scores/2017/339/MS004/match-stats
# 1              0  2017-339-d875-n552  /en/scores/2017/339/MS001/match-stats
# 2              0  2017-339-d875-r975  /en/scores/2017/339/MS002/match-stats
# 3              0  2017-339-n552-w367  /en/scores/2017/339/MS003/match-stats
# 4              0  2017-339-d875-tb69  /en/scores/2017/339/MS005/match-stats
#
#   match_time  match_duration  winner_aces  winner_double_faults  \
# 0   02:21:00             141           23                     3
# 1   01:49:00             109            7                     2
# 2   01:28:00              88            4                     1
# 3   01:42:00             102            1                     1
# 4   02:05:00             125            3                     3
#
#    winner_first_serves_in  winner_first_serves_total  \
# 0                      62                         97
# ...

# %%
stats_df["winner_id"] = 1

# %%
stats_df["loser_id"] = 2

# %%
new_df = stats_df.drop(["winner_total_points_won","loser_total_points_won","winner_total_points_total"], axis=1)

# %%
new_df.head()
# Out:
#    tourney_order            match_id                 match_stats_url_suffix  \
# 0              0  2017-339-r975-n409  /en/scores/2017/339/MS004/match-stats
# 1              0  2017-339-d875-n552  /en/scores/2017/339/MS001/match-stats
# 2              0  2017-339-d875-r975  /en/scores/2017/339/MS002/match-stats
# 3              0  2017-339-n552-w367  /en/scores/2017/339/MS003/match-stats
# 4              0  2017-339-d875-tb69  /en/scores/2017/339/MS005/match-stats
#
#   match_time  match_duration  winner_aces  winner_double_faults  \
# 0   02:21:00             141           23                     3
# 1   01:49:00             109            7                     2
# 2   01:28:00              88            4                     1
# 3   01:42:00             102            1                     1
# 4   02:05:00             125            3                     3
#
#    winner_first_serves_in  winner_first_serves_total  \
# 0                      62                         97
# ...

# %%
stats_df["outcome"] = np.where(stats_df["winner_total_points_won"] > stats_df["loser_total_points_won"], 1, 2)

# %%
y = stats_df["outcome"]

# %%
X = stats_df.drop(["outcome","match_id","match_time"], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
   max_iter=200,
   random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 classifier.fit(X_train, y_train)
#
# File ~/miniforge3/envs/mlenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1508, in LogisticRegression.fit(self, X, y, sample_weight)
#    1505 else:
#    1506     _dtype = [np.float64, np.float32]
# -> 1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    1511     accept_sparse="csr",
#    1512     dtype=_dtype,
#    1513     order="C",
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
#    1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#
# File ~/miniforge3/envs/mlenv/lib/python3.8/site-packages/sklearn/base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# %% [markdown]
# # Reading in all csv's

# %%
stats_2017_df = pd.read_csv(file_path)

# %%
stats_2017_df.head()
# Out:
#    tourney_order            match_id                 match_stats_url_suffix  \
# 0              0  2017-339-r975-n409  /en/scores/2017/339/MS004/match-stats
# 1              0  2017-339-d875-n552  /en/scores/2017/339/MS001/match-stats
# 2              0  2017-339-d875-r975  /en/scores/2017/339/MS002/match-stats
# 3              0  2017-339-n552-w367  /en/scores/2017/339/MS003/match-stats
# 4              0  2017-339-d875-tb69  /en/scores/2017/339/MS005/match-stats
#
#   match_time  match_duration  winner_aces  winner_double_faults  \
# 0   02:21:00             141           23                     3
# 1   01:49:00             109            7                     2
# 2   01:28:00              88            4                     1
# 3   01:42:00             102            1                     1
# 4   02:05:00             125            3                     3
#
#    winner_first_serves_in  winner_first_serves_total  \
# 0                      62                         97
# ...

# %%
scores_2017_df = pd.read_csv("../tennis_predictor/Resources/original_data/match_scores_2017.csv")

# %%
scores_2017_df.head()
# Out:
#   tourney_year_id  tourney_order tourney_slug  \
# 0        2017-339              1     brisbane
# 1        2017-339              1     brisbane
# 2        2017-339              1     brisbane
# 3        2017-339              1     brisbane
# 4        2017-339              1     brisbane
#
#                              tourney_url_suffix tourney_round_name  \
# 0  /en/scores/archive/brisbane/339/2017/results             Finals
# 1  /en/scores/archive/brisbane/339/2017/results        Semi-Finals
# 2  /en/scores/archive/brisbane/339/2017/results        Semi-Finals
# 3  /en/scores/archive/brisbane/339/2017/results     Quarter-Finals
# 4  /en/scores/archive/brisbane/339/2017/results     Quarter-Finals
#
#    round_order  match_order      winner_name winner_player_id  \
# 0            1            1  Grigor Dimitrov             d875
# 1            2            1  Grigor Dimitrov             d875
# 2            2            2    Kei Nishikori             n552
# ...

# %%
# Merge 2017 Scores on 2017 Stats Test 1
scores_stats_2017_df = scores_2017_df.merge(stats_2017_df, how='inner', on='match_id')

# %%
# Checked merged df
scores_stats_2017_df.head()
# Out:
#   tourney_year_id  tourney_order_x tourney_slug  \
# 0        2017-339                1     brisbane
# 1        2017-339                1     brisbane
# 2        2017-339                1     brisbane
# 3        2017-339                1     brisbane
# 4        2017-339                1     brisbane
#
#                              tourney_url_suffix tourney_round_name  \
# 0  /en/scores/archive/brisbane/339/2017/results             Finals
# 1  /en/scores/archive/brisbane/339/2017/results        Semi-Finals
# 2  /en/scores/archive/brisbane/339/2017/results        Semi-Finals
# 3  /en/scores/archive/brisbane/339/2017/results     Quarter-Finals
# 4  /en/scores/archive/brisbane/339/2017/results     Quarter-Finals
#
#    round_order  match_order      winner_name winner_player_id  \
# 0            1            1  Grigor Dimitrov             d875
# 1            2            1  Grigor Dimitrov             d875
# 2            2            2    Kei Nishikori             n552
# ...

# %%
# Read in scores and stats from 1991-2016
scores_1991_2016_df = pd.read_csv("../tennis_predictor/Resources/original_data/match_scores_1991-2016.csv")
stats_1991_2016_df = pd.read_csv("../tennis_predictor/Resources/original_data/match_stats_1991-2016.csv")

# %%
# Merge 1991-2016 scores and stats
scores_stats_1991_2016_df = scores_1991_2016_df.merge(stats_1991_2016_df, how='inner', on='match_id')

# %%
# Check merged df
scores_stats_1991_2016_df.head()
# Out:
#   tourney_year_id  tourney_order_x tourney_slug  \
# 0       1991-7308                1     adelaide
# 1       1991-7308                1     adelaide
# 2       1991-7308                1     adelaide
# 3       1991-7308                1     adelaide
# 4       1991-7308                1     adelaide
#
#                               tourney_url_suffix tourney_round_name  \
# 0  /en/scores/archive/adelaide/7308/1991/results             Finals
# 1  /en/scores/archive/adelaide/7308/1991/results        Semi-Finals
# 2  /en/scores/archive/adelaide/7308/1991/results        Semi-Finals
# 3  /en/scores/archive/adelaide/7308/1991/results     Quarter-Finals
# 4  /en/scores/archive/adelaide/7308/1991/results     Quarter-Finals
#
#    round_order  match_order    winner_name winner_player_id    winner_slug  \
# 0            1            1  Nicklas Kulti             k181  nicklas-kulti
# 1            2            1  Michael Stich             s351  michael-stich
# ...

# %%
scores_stats_1991_2016_df.dtypes
# Out:
# tourney_year_id               object
# tourney_order_x                int64
# tourney_slug                  object
# tourney_url_suffix            object
# tourney_round_name            object
#                               ...
# loser_return_games_played    float64
# loser_return_points_won      float64
# loser_return_points_total    float64
# loser_total_points_won       float64
# loser_total_points_total     float64
# Length: 76, dtype: object

# %%
scores_stats_2017_df.dtypes
# Out:
# tourney_year_id              object
# tourney_order_x               int64
# tourney_slug                 object
# tourney_url_suffix           object
# tourney_round_name           object
#                               ...
# loser_return_games_played     int64
# loser_return_points_won       int64
# loser_return_points_total     int64
# loser_total_points_won        int64
# loser_total_points_total      int64
# Length: 76, dtype: object

# %%
# Normalize datatypes from int64 to float64
scores_stats_2017_df.head()
# Out:
#   tourney_year_id  tourney_order_x tourney_slug  \
# 0        2017-339                1     brisbane
# 1        2017-339                1     brisbane
# 2        2017-339                1     brisbane
# 3        2017-339                1     brisbane
# 4        2017-339                1     brisbane
#
#                              tourney_url_suffix tourney_round_name  \
# 0  /en/scores/archive/brisbane/339/2017/results             Finals
# 1  /en/scores/archive/brisbane/339/2017/results        Semi-Finals
# 2  /en/scores/archive/brisbane/339/2017/results        Semi-Finals
# 3  /en/scores/archive/brisbane/339/2017/results     Quarter-Finals
# 4  /en/scores/archive/brisbane/339/2017/results     Quarter-Finals
#
#    round_order  match_order      winner_name winner_player_id  \
# 0            1            1  Grigor Dimitrov             d875
# 1            2            1  Grigor Dimitrov             d875
# 2            2            2    Kei Nishikori             n552
# ...

# %%
for index in range(scores_stats_2017_df.shape[1]):
    
    print('Column Number : ', index)
     
    # Select column by index position using iloc[]
    columnSeriesObj = scores_stats_2017_df.iloc[:, index]
    print('Column Contents : ', columnSeriesObj.dtype)
    if columnSeriesObj.dtype = int64:
# Out:
# Column Number :  0
# Column Contents :  object
# Column Number :  1
# Column Contents :  int64
# Column Number :  2
# Column Contents :  object
# Column Number :  3
# Column Contents :  object
# Column Number :  4
# Column Contents :  object
# Column Number :  5
# Column Contents :  int64
# Column Number :  6
# Column Contents :  int64
# Column Number :  7
# Column Contents :  object
# Column Number :  8
# Column Contents :  object
# Column Number :  9
# Column Contents :  object
# Column Number :  10
# Column Contents :  object
# Column Number :  11
# Column Contents :  object
# Column Number :  12
# Column Contents :  object
# Column Number :  13
# Column Contents :  object
# Column Number :  14
# Column Contents :  object
# Column Number :  15
# Column Contents :  object
# Column Number :  16
# Column Contents :  int64
# Column Number :  17
# Column Contents :  int64
# Column Number :  18
# Column Contents :  int64
# Column Number :  19
# Column Contents :  int64
# ...
